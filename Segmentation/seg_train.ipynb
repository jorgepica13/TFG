# %%
# We start by getting access to the drive
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import sys,os
# change directory
# %cd '/content/drive/My Drive'
# Let's import the python module exercises.py  to have access to its functions and Classes
path_to_module='/content/drive/My Drive/segmentation_codes/'
sys.path.append(os.path.abspath(path_to_module))
import seg_datasets, seg_engine, seg_model, seg_config_bin, seg_utils
# Out:
# /content/drive/My Drive

# %%
import torch
import torch.nn as nn
import os
# import argparse

# from datasets import get_images, get_dataset, get_data_loaders
# from engine import train, validate
# from model import prepare_model
# from config_bin import ALL_CLASSES, LABEL_COLORS_LIST
# from seg_utils import save_model, SaveBestModel, save_plots
# from torch.optim.lr_scheduler import StepLR

seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

lr = 1e-4
imgsz = 256
batch = 32
epochs = 20
scheduler = True

'''
parser = argparse.ArgumentParser()
parser.add_argument(
    '--epochs',
    default=10,
    help='number of epochs to train for',
    type=int
)
parser.add_argument(
    '--lr',
    default=0.0001,
    help='learning rate for optimizer',
    type=float
)
parser.add_argument(
    '--batch',
    default=4,
    help='batch size for data loader',
    type=int
)
parser.add_argument(
    '--imgsz', 
    default=512,
    type=int
)
parser.add_argument(
    '--scheduler',
    action='store_true',
)
args = parser.parse_args()
print(args)
'''
# Out:
# "\nparser = argparse.ArgumentParser()\nparser.add_argument(\n    '--epochs',\n    default=10,\n    help='number of epochs to train for',\n    type=int\n)\nparser.add_argument(\n    '--lr',\n    default=0.0001,\n    help='learning rate for optimizer',\n    type=float\n)\nparser.add_argument(\n    '--batch',\n    default=4,\n    help='batch size for data loader',\n    type=int\n)\nparser.add_argument(\n    '--imgsz', \n    default=512,\n    type=int\n)\nparser.add_argument(\n    '--scheduler',\n    action='store_true',\n)\nargs = parser.parse_args()\nprint(args)\n"

# %%
if __name__ == '__main__':
    # Create a directory with the model name for outputs.
    out_dir = '/content/drive/My Drive/segmentation_codes/outputs_bin/'
    out_dir_valid_preds = os.path.join(out_dir, 'valid_preds')
    os.makedirs(out_dir, exist_ok=True)
    os.makedirs(out_dir_valid_preds, exist_ok=True)

    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    model = seg_model.prepare_model(num_classes=len(seg_config_bin.ALL_CLASSES)).to(device)
    # Total parameters and trainable parameters.
    total_params = sum(p.numel() for p in model.parameters())
    print(f"{total_params:,} total parameters.")
    total_trainable_params = sum(
        p.numel() for p in model.parameters() if p.requires_grad)
    print(f"{total_trainable_params:,} training parameters.")

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    train_images, train_masks, valid_images, valid_masks = seg_datasets.get_images(
        root_path='/content/drive/My Drive/galaxy_binary_seg/'    
    )

    classes_to_train = seg_config_bin.ALL_CLASSES

    train_dataset, valid_dataset = seg_datasets.get_dataset(
        train_images, 
        train_masks,
        valid_images,
        valid_masks,
        seg_config_bin.ALL_CLASSES,
        classes_to_train,
        seg_config_bin.LABEL_COLORS_LIST,
        img_size=imgsz
    )

    train_dataloader, valid_dataloader = seg_datasets.get_data_loaders(
        train_dataset, valid_dataset, batch_size=batch
    )

    # Initialize `SaveBestModel` class.
    save_best_model = seg_utils.SaveBestModel()
    # LR Scheduler.
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=25, gamma=0.1, verbose=True)

    EPOCHS = epochs
    train_loss, train_pix_acc = [], []
    valid_loss, valid_pix_acc = [], []
    for epoch in range (EPOCHS):
        print(f"EPOCH: {epoch + 1}")
        train_epoch_loss, train_epoch_pixacc = seg_engine.train(
            model,
            train_dataset,
            train_dataloader,
            device,
            optimizer,
            criterion,
            classes_to_train
        )
        valid_epoch_loss, valid_epoch_pixacc = seg_engine.validate(
            model,
            valid_dataset,
            valid_dataloader,
            device,
            criterion,
            classes_to_train,
            seg_config_bin.LABEL_COLORS_LIST,
            epoch,
            seg_config_bin.ALL_CLASSES,
            save_dir=out_dir_valid_preds
        )
        train_loss.append(train_epoch_loss)
        train_pix_acc.append(train_epoch_pixacc.cpu())
        valid_loss.append(valid_epoch_loss)
        valid_pix_acc.append(valid_epoch_pixacc.cpu())

        save_best_model(
            valid_epoch_loss, epoch, model, out_dir
        )

        print(f"Train Epoch Loss: {train_epoch_loss:.4f}, Train Epoch PixAcc: {train_epoch_pixacc:.4f}")
        print(f"Valid Epoch Loss: {valid_epoch_loss:.4f}, Valid Epoch PixAcc: {valid_epoch_pixacc:.4f}")
        if scheduler:
            scheduler.step()
        print('-' * 50)

    seg_utils.save_model(EPOCHS, model, optimizer, criterion, out_dir)
    # Save the loss and accuracy plots.
    seg_utils.save_plots(
        train_pix_acc, valid_pix_acc, train_loss, valid_loss, out_dir
    )
    print('TRAINING COMPLETE')
# Out:
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet50_coco-cd0a2569.pth" to /root/.cache/torch/hub/checkpoints/deeplabv3_resnet50_coco-cd0a2569.pth
# 100%|██████████| 161M/161M [00:00<00:00, 225MB/s]
# 41,994,308 total parameters.
# 41,994,308 training parameters.
# Adjusting learning rate of group 0 to 1.0000e-04.
# EPOCH: 1
# Training
#   0%|                    | 0/89 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/albumentations/augmentations/functional.py:764: UserWarning: Image compression augmentation is most effective with uint8 inputs, float32 is used as input.
#   warn(
# Loss: 0.1393 | PixAcc: 84.21: 100%|████████████████████| 89/89 [20:04<00:00, 13.53s/it]
# Validating
# Loss: 0.1283 | PixAcc: 76.53: 100%|████████████████████| 8/8 [02:38<00:00, 19.80s/it]
# Best validation loss: 0.12979760020971298
#
# Saving best model for epoch: 1
#
# Train Epoch Loss: 0.2689, Train Epoch PixAcc: 69.6292
# Valid Epoch Loss: 0.1298, Valid Epoch PixAcc: 78.7967
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 2
# Training
# Loss: 0.0896 | PixAcc: 87.16: 100%|████████████████████| 89/89 [05:16<00:00,  3.56s/it]
# Validating
# Loss: 0.0726 | PixAcc: 94.94: 100%|████████████████████| 8/8 [00:08<00:00,  1.12s/it]
# Best validation loss: 0.07394756376743317
#
# Saving best model for epoch: 2
#
# Train Epoch Loss: 0.1052, Train Epoch PixAcc: 78.3749
# Valid Epoch Loss: 0.0739, Valid Epoch PixAcc: 94.8153
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 3
# Training
# Loss: 0.0665 | PixAcc: 82.42: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0510 | PixAcc: 95.63: 100%|████████████████████| 8/8 [00:09<00:00,  1.16s/it]
# Best validation loss: 0.052653232123702765
#
# Saving best model for epoch: 3
#
# Train Epoch Loss: 0.0675, Train Epoch PixAcc: 80.8440
# Valid Epoch Loss: 0.0527, Valid Epoch PixAcc: 93.7895
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 4
# Training
# Loss: 0.0418 | PixAcc: 88.76: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0349 | PixAcc: 92.27: 100%|████████████████████| 8/8 [00:09<00:00,  1.16s/it]
# Best validation loss: 0.03597948653623462
#
# Saving best model for epoch: 4
#
# Train Epoch Loss: 0.0486, Train Epoch PixAcc: 81.7450
# Valid Epoch Loss: 0.0360, Valid Epoch PixAcc: 92.3651
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 5
# Training
# Loss: 0.0375 | PixAcc: 89.78: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0262 | PixAcc: 93.19: 100%|████████████████████| 8/8 [00:09<00:00,  1.16s/it]
# Best validation loss: 0.02900799224153161
#
# Saving best model for epoch: 5
#
# Train Epoch Loss: 0.0378, Train Epoch PixAcc: 82.2489
# Valid Epoch Loss: 0.0290, Valid Epoch PixAcc: 93.4106
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 6
# Training
# Loss: 0.0279 | PixAcc: 90.67: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0237 | PixAcc: 94.98: 100%|████████████████████| 8/8 [00:08<00:00,  1.12s/it]
# Best validation loss: 0.026961517753079534
#
# Saving best model for epoch: 6
#
# Train Epoch Loss: 0.0316, Train Epoch PixAcc: 82.9070
# Valid Epoch Loss: 0.0270, Valid Epoch PixAcc: 94.9081
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 7
# Training
# Loss: 0.0250 | PixAcc: 92.96: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0177 | PixAcc: 94.78: 100%|████████████████████| 8/8 [00:09<00:00,  1.15s/it]
# Best validation loss: 0.02137283538468182
#
# Saving best model for epoch: 7
#
# Train Epoch Loss: 0.0266, Train Epoch PixAcc: 83.7126
# Valid Epoch Loss: 0.0214, Valid Epoch PixAcc: 95.0070
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 8
# Training
# Loss: 0.0245 | PixAcc: 92.71: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0175 | PixAcc: 95.90: 100%|████████████████████| 8/8 [00:09<00:00,  1.17s/it]
# Best validation loss: 0.02118482021614909
#
# Saving best model for epoch: 8
#
# Train Epoch Loss: 0.0242, Train Epoch PixAcc: 83.4921
# Valid Epoch Loss: 0.0212, Valid Epoch PixAcc: 94.6016
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 9
# Training
# Loss: 0.0180 | PixAcc: 91.55: 100%|████████████████████| 89/89 [05:19<00:00,  3.59s/it]
# Validating
# Loss: 0.0137 | PixAcc: 91.35: 100%|████████████████████| 8/8 [00:09<00:00,  1.16s/it]
# Best validation loss: 0.015723349060863256
#
# Saving best model for epoch: 9
#
# Train Epoch Loss: 0.0221, Train Epoch PixAcc: 83.4584
# Valid Epoch Loss: 0.0157, Valid Epoch PixAcc: 90.1933
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 10
# Training
# Loss: 0.0191 | PixAcc: 92.75: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0143 | PixAcc: 95.89: 100%|████████████████████| 8/8 [00:09<00:00,  1.14s/it]
# Train Epoch Loss: 0.0196, Train Epoch PixAcc: 85.0673
# Valid Epoch Loss: 0.0169, Valid Epoch PixAcc: 94.7771
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 11
# Training
# Loss: 0.0200 | PixAcc: 91.10: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0130 | PixAcc: 97.39: 100%|████████████████████| 8/8 [00:09<00:00,  1.15s/it]
# Train Epoch Loss: 0.0180, Train Epoch PixAcc: 85.8136
# Valid Epoch Loss: 0.0161, Valid Epoch PixAcc: 95.9489
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 12
# Training
# Loss: 0.0135 | PixAcc: 93.70: 100%|████████████████████| 89/89 [05:19<00:00,  3.59s/it]
# Validating
# Loss: 0.0110 | PixAcc: 91.39: 100%|████████████████████| 8/8 [00:09<00:00,  1.16s/it]
# Best validation loss: 0.013161986600607634
#
# Saving best model for epoch: 12
#
# Train Epoch Loss: 0.0171, Train Epoch PixAcc: 85.5515
# Valid Epoch Loss: 0.0132, Valid Epoch PixAcc: 92.4366
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 13
# Training
# Loss: 0.0159 | PixAcc: 91.51: 100%|████████████████████| 89/89 [05:19<00:00,  3.60s/it]
# Validating
# Loss: 0.0110 | PixAcc: 95.08: 100%|████████████████████| 8/8 [00:09<00:00,  1.17s/it]
# Train Epoch Loss: 0.0167, Train Epoch PixAcc: 84.9554
# Valid Epoch Loss: 0.0150, Valid Epoch PixAcc: 92.4295
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 14
# Training
# Loss: 0.0123 | PixAcc: 91.44: 100%|████████████████████| 89/89 [05:19<00:00,  3.59s/it]
# Validating
# Loss: 0.0100 | PixAcc: 96.48: 100%|████████████████████| 8/8 [00:09<00:00,  1.14s/it]
# Best validation loss: 0.012667006230913103
#
# Saving best model for epoch: 14
#
# Train Epoch Loss: 0.0155, Train Epoch PixAcc: 86.1697
# Valid Epoch Loss: 0.0127, Valid Epoch PixAcc: 94.3875
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 15
# Training
# Loss: 0.0119 | PixAcc: 93.95: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0090 | PixAcc: 89.85: 100%|████████████████████| 8/8 [00:09<00:00,  1.13s/it]
# Best validation loss: 0.010117068537510931
#
# Saving best model for epoch: 15
#
# Train Epoch Loss: 0.0158, Train Epoch PixAcc: 85.4560
# Valid Epoch Loss: 0.0101, Valid Epoch PixAcc: 91.1279
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 16
# Training
# Loss: 0.0126 | PixAcc: 87.92: 100%|████████████████████| 89/89 [05:19<00:00,  3.60s/it]
# Validating
# Loss: 0.0084 | PixAcc: 93.16: 100%|████████████████████| 8/8 [00:09<00:00,  1.17s/it]
# Train Epoch Loss: 0.0146, Train Epoch PixAcc: 86.3109
# Valid Epoch Loss: 0.0106, Valid Epoch PixAcc: 92.7743
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 17
# Training
# Loss: 0.0130 | PixAcc: 91.18: 100%|████████████████████| 89/89 [05:19<00:00,  3.59s/it]
# Validating
# Loss: 0.0097 | PixAcc: 96.81: 100%|████████████████████| 8/8 [00:09<00:00,  1.16s/it]
# Train Epoch Loss: 0.0144, Train Epoch PixAcc: 85.9080
# Valid Epoch Loss: 0.0137, Valid Epoch PixAcc: 96.0761
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 18
# Training
# Loss: 0.0129 | PixAcc: 84.47: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0079 | PixAcc: 94.22: 100%|████████████████████| 8/8 [00:09<00:00,  1.13s/it]
# Train Epoch Loss: 0.0139, Train Epoch PixAcc: 86.2851
# Valid Epoch Loss: 0.0107, Valid Epoch PixAcc: 93.8269
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 19
# Training
# Loss: 0.0110 | PixAcc: 89.79: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0071 | PixAcc: 94.04: 100%|████████████████████| 8/8 [00:09<00:00,  1.13s/it]
# Best validation loss: 0.009938771720044315
#
# Saving best model for epoch: 19
#
# Train Epoch Loss: 0.0128, Train Epoch PixAcc: 87.1949
# Valid Epoch Loss: 0.0099, Valid Epoch PixAcc: 94.4128
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# EPOCH: 20
# Training
# Loss: 0.0134 | PixAcc: 87.49: 100%|████████████████████| 89/89 [05:20<00:00,  3.60s/it]
# Validating
# Loss: 0.0075 | PixAcc: 94.83: 100%|████████████████████| 8/8 [00:09<00:00,  1.16s/it]
# Train Epoch Loss: 0.0136, Train Epoch PixAcc: 86.1265
# Valid Epoch Loss: 0.0126, Valid Epoch PixAcc: 93.3544
# Adjusting learning rate of group 0 to 1.0000e-04.
# --------------------------------------------------
# TRAINING COMPLETE
